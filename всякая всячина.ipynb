# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter, defaultdict
from collections import OrderedDict as od
from pprint import pprint
from pymystem3 import Mystem
m = Mystem()
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from gensim.models import word2vec
from natasha.extractors import NamesExtractor, LocationExtractor, AddressExtractor
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()
import jsonlines

# %%
def data(text, new_file):
    with open (text, encoding = 'utf-8') as f:
        big_text = f.read()
        tok = word_tokenize(big_text)
        for w in tok:
            p = morph.parse(w)[0]
            info = {'lemma' : p.normal_form, 'word': p.word, 'pos': p.tag.POS}
            with jsonlines.open(new_file, mode='a') as writer:
                writer.write(info)
    return new_file

# %%
def picture(data):
    my_data = []
    with jsonlines.open(data) as reader:
        for line in reader.iter():
            my_data.append(line)
    df = pd.DataFrame(my_data)
    df['pos'].value_counts().plot.bar(color='mediumslateblue');
    plt.title('Part of Speech')
    plt.xlabel('pos')
    plt.ylabel('number of entries');

# %%
#g = data('Glinka.txt', 'info_Glinka.jsonl')
#l = data('Lazhechnikov.txt', 'info_Lazhechnikov.jsonl')
#d = data('Durova.txt', 'info_Durova.jsonl')
#dav = data('Davydov.txt', 'info_Davydov.jsonl')
#sr = data('smirnova-rosset.txt', 'info_Smirnova.jsonl')
v = data('Durova_Nevygody3Poseshceniya.txt', 'info_Durova2.jsonl')

# %%
gg = 'info_Glinka.jsonl'
ll = 'info_Lazhechnikov.jsonl'
dd = 'info_Durova.jsonl'
ddav = 'info_Davydov.jsonl'
ssrr = 'info_Smirnova.jsonl'
vv = 'info_Durova2.jsonl'

# %%
def table(mdata):
    my_data = []
    with jsonlines.open(mdata) as reader:
        for line in reader.iter():
            if not line['pos'] == 'null' and not line['pos'] == None:
                my_data.append(line)
                #print(line)
    return my_data

# %%
g_df = table(gg)
gg_df = pd.DataFrame(g_df)
l_df = table(ll)
ll_df = pd.DataFrame(l_df)
d_df = table(dd)
dd_df = pd.DataFrame(d_df)
dav_df = table(ddav)
ddav_df = pd.DataFrame(dav_df)
sr_df = table(ssrr)
ssrr_df = pd.DataFrame(sr_df)
v_df = table(vv)
vv_df = pd.DataFrame(v_df)

# %%
def new_pos(text):
    if text in ['ADJF', 'ADJS']:
        return 'ADJ'
    elif text in ["GRND", "PRTF", "PRTS", "INFN", "VERB"]:
        return "VERB"
    else:
        return text
gg_df["pos_two"] = gg_df["pos"].apply(new_pos)
ll_df["pos_two"] = ll_df["pos"].apply(new_pos)
dd_df["pos_two"] = dd_df["pos"].apply(new_pos)
ddav_df["pos_two"] = ddav_df["pos"].apply(new_pos)
ssrr_df["pos_two"] = ssrr_df["pos"].apply(new_pos)
vv_df["pos_two"] = vv_df["pos"].apply(new_pos)

# %%
def part_o_s(dataf):
    pos = dict(dataf['pos_two'].value_counts())
    total = sum(pos.values())
    for k, v in pos.items():
        pos[k] = (v/total)*100
    return pos

# %%
g_pos = part_o_s(gg_df)
l_pos = part_o_s(ll_df)
d_pos = part_o_s(dd_df)
dav_pos = part_o_s(ddav_df)
sr_pos = part_o_s(ssrr_df)
v_pos = part_o_s(vv_df)

# %%
def sort(my_dict, keys, new_dict):
    for i in keys:
        new_dict[i] = my_dict[i]
    return new_dict

# %%
k = ['NOUN','VERB', 'ADJ','PREP','CONJ','NPRO','ADVB','PRCL','NUMR','COMP','PRED','INTJ']
new_d_g = {}
new_d_l = {}
new_d_dav = {}
new_d_d = {}
new_d_sr = {}
new_d_v = {}
g_pos_sort = sort(g_pos, k, new_d_g)
l_pos_sort = sort(l_pos, k, new_d_l)
dav_pos_sort = sort(dav_pos, k, new_d_dav)
d_pos_sort = sort(d_pos, k, new_d_d)
sr_pos_sort = sort(sr_pos, k, new_d_sr)
v_pos_sort = sort(v_pos, k, new_d_v)

# %%
def lemmas(df):
    p_lemmas = defaultdict(list)
    for i in df:
        if i['pos']  in ['ADJF', 'ADJS']:
            i['pos'] = 'ADJ'
        elif i['pos'] in ["GRND", "PRTF", "PRTS", "INFN", "VERB"]:
            i['pos'] = "VERB"
        p_lemmas[i['pos']].append(i['lemma'])
    return p_lemmas

# %%
g_lemmas_pos = lemmas(g_df)
l_lemmas_pos = lemmas(l_df)
d_lemmas_pos = lemmas(d_df)
dav_lemmas_pos = lemmas(dav_df)
sr_lemmas_pos = lemmas(sr_df)
v_lemmas_pos = lemmas(v_df)

# %%
def count_all(data, p):
    a = 0
    for pos in p:
        print(pos, len(data[pos]))
        a += len(data[pos])
    print(a)

# %%
def count_my_pos (my_list, pos, most):
    tot = len(my_list[pos])
    c = Counter(my_list[pos]).most_common(most)
    print('word', 'abs', 'percent')
    for cc in c:
        p = (cc[1]/tot)*100
        print(cc[0], cc[1], p)

# %%
d_lemmas_pos = lemmas(d_df)
count_my_pos (d_lemmas_pos, 'NPRO', 10)
# Out:
# word abs percent
# я 4585 42.38306526160103
# он 1773 16.38935108153078
# она 883 8.16232205583287
# мы 709 6.55389166204474
# они 624 5.7681641708264
# вы 529 4.889998151229433
# это 456 4.215196894065446
# ты 362 3.346274727306341
# себя 268 2.477352560547236
# ничто 136 1.2571639859493438

# %%
g_lemmas_pos = lemmas(g_df)
count_my_pos (g_lemmas_pos, 'NPRO', 10)
# Out:
# word abs percent
# он 1113 25.135501355013552
# они 738 16.666666666666664
# мы 676 15.266485998193316
# я 473 10.682023486901535
# она 418 9.43992773261066
# себя 225 5.08130081300813
# вы 151 3.4101174345076783
# ты 144 3.2520325203252036
# это 106 2.3938572719060525
# кто 84 1.8970189701897018

# %%
l_lemmas_pos = lemmas(l_df)
count_my_pos (l_lemmas_pos, 'NPRO', 10)
# Out:
# word abs percent
# он 900 32.07412687099073
# они 460 16.39344262295082
# я 366 13.043478260869565
# она 310 11.047754811119031
# мы 254 9.052031361368496
# вы 143 5.096222380612972
# себя 113 4.027084818246615
# это 103 3.6707056307911614
# кто 41 1.4611546685673558
# ты 24 0.8553100498930863

# %%
dav_lemmas_pos = lemmas(dav_df)
count_my_pos (dav_lemmas_pos, 'NPRO', 10)
# Out:
# word abs percent
# я 810 34.571062740076826
# он 699 29.833546734955185
# мы 255 10.88348271446863
# они 205 8.74946649594537
# она 79 3.371745625266752
# себя 67 2.8595817328211695
# вы 55 2.3474178403755865
# это 47 2.0059752454118653
# ты 36 1.5364916773367476
# что 23 0.9816474605207

# %%
def words(lemmas_pos, slova, pos):
    len_l = len(lemmas_pos[pos])
    print(len_l)
    print(set(lemmas_pos[pos]))
    c = Counter(lemmas_pos[pos]).most_common()
    diction = od({})
    for s in slova:
        diction[s] = 0
    for cc in c:
        if cc[0] in slova:
            v =((cc[1]/len_l)*100)
            diction[cc[0]] = v
    return diction

# %%
slova = ['я', 'ты', 'он', 'она', 'оно', 'мы', 'вы', 'они']
print('Glinka')
npro_g = words(g_lemmas_pos, slova, 'NPRO')
pprint(npro_g)
print('Lazhechnikov')
npro_l = words(l_lemmas_pos, slova, 'NPRO')
pprint(npro_l)
print('Davydov')
npro_dav = words(dav_lemmas_pos, slova, 'NPRO')
pprint(npro_dav)
print('Durova')
npro_d = words(d_lemmas_pos, slova, 'NPRO')
pprint(npro_d)
print('Smirnova-Rosset')
npro_sr = words(sr_lemmas_pos, slova, 'NPRO')
pprint(npro_sr)
print('Год жизни в Петербурге')
npro_v = words(v_lemmas_pos, slova, 'NPRO')
pprint(npro_v)
# Out:
# Glinka
# 4428
# {'нечто', 'мы', 'оно', 'некто', 'они', 'прочее', 'многое', 'кто-нибудь', 'кто-то', 'это', 'она-то', 'кое-что', 'некоторые', 'он', 'вы', 'ничто', 'ты', 'никто', 'что-то', 'нечего', 'я', 'что-нибудь', 'что', 'она', 'себя', 'многие', 'кто', 'всякая'}
# OrderedDict([('я', 10.682023486901535),
#              ('ты', 3.2520325203252036),
#              ('он', 25.135501355013552),
#              ('она', 9.43992773261066),
#              ('оно', 1.038843721770551),
#              ('мы', 15.266485998193316),
#              ('вы', 3.4101174345076783),
#              ('они', 16.666666666666664)])
# Lazhechnikov
# 2806
# {'нечто', 'мы', 'оно', 'они', 'прочее', 'кто-нибудь', 'это', 'некоторые', 'он', 'вы', 'ничто', 'ты', 'никто', 'что-то', 'я', 'что', 'она', 'себя', 'многие', 'всякая', 'кто', 'что-нибудь', 'любой'}
# OrderedDict([('я', 13.043478260869565),
#              ('ты', 0.8553100498930863),
#              ('он', 32.07412687099073),
#              ('она', 11.047754811119031),
#              ('оно', 0.6058446186742694),
#              ('мы', 9.052031361368496),
#              ('вы', 5.096222380612972),
#              ('они', 16.39344262295082)])
# Davydov
# 2343
# {'3-я', 'мы', 'оно', 'некого', 'они', 'прочее', 'это', 'некоторые', 'он', 'кто-либо', 'вы', 'ничто', 'ты', 'никто', 'нечего', 'я', 'что-нибудь', '4-я', 'что', '2-я', 'она', 'себя', 'многие', 'кто', 'всякая'}
# OrderedDict([('я', 34.571062740076826),
#              ('ты', 1.5364916773367476),
#              ('он', 29.833546734955185),
#              ('она', 3.371745625266752),
#              ('оно', 0.3841229193341869),
#              ('мы', 10.88348271446863),
#              ('вы', 2.3474178403755865),
#              ('они', 8.74946649594537)])
# Durova
# 10818
# {'нечто', 'мы', 'оно', 'некого', 'они', 'прочее', 'многое', 'кто-нибудь', 'кто-то', 'это', 'некоторые', 'он', 'вы', 'ничто', 'ты', 'никто', 'что-то', 'что-либо', 'нечего', 'он-то', 'я', 'что-нибудь', 'что', 'ты-то', 'она', 'себя', 'многие', 'кой-что', 'кто', 'всякая'}
# OrderedDict([('я', 42.38306526160103),
#              ('ты', 3.346274727306341),
#              ('он', 16.38935108153078),
#              ('она', 8.16232205583287),
#              ('оно', 0.24958402662229617),
#              ('мы', 6.55389166204474),
#              ('вы', 4.889998151229433),
#              ('они', 5.7681641708264)])
# Smirnova-Rosset
# 1377
# {'кто-нибудь', 'вы', 'что-то', 'это', 'она', 'кое-что', 'мы', 'себя', 'оно', 'он', 'я', 'некоторые', 'кто', 'всякая', 'ничто', 'они', 'ты', 'никто'}
# OrderedDict([('я', 29.847494553376908),
#              ('ты', 0.2178649237472767),
#              ('он', 32.24400871459695),
#              ('она', 12.418300653594772),
#              ('оно', 0.6535947712418301),
#              ('мы', 3.485838779956427),
#              ('вы', 2.832244008714597),
#              ('они', 7.4074074074074066)])
# Год жизни в Петербурге
# 4116
# {'нечто', 'мы', 'оно', 'некого', 'они', 'прочее', 'многое', 'кто-то', 'кто-нибудь', 'это', 'кое-что', 'он', 'вы', 'ничто', 'ты', 'никто', 'что-то', 'нечего', 'я', 'что-нибудь', 'что', 'она', 'себя', 'кто', 'всякая'}
# OrderedDict([('я', 44.70359572400389),
#              ('ты', 0.9718172983479106),
#              ('он', 10.00971817298348),
#              ('она', 11.467444120505345),
#              ('оно', 0.4859086491739553),
#              ('мы', 2.0894071914480077),
#              ('вы', 10.349854227405247),
#              ('они', 6.2682215743440235)])

# %%
slova = ['ах', 'ура', 'увы']
print('Glinka')
intj_g = words(g_lemmas_pos, slova, 'INTJ')
pprint(intj_g)
print('Lazhechnikov')
intj_l = words(l_lemmas_pos, slova, 'INTJ')
pprint(intj_l)
print('Davydov')
intj_dav = words(dav_lemmas_pos, slova, 'INTJ')
pprint(intj_dav)
print('Durova')
intj_d = words(d_lemmas_pos, slova, 'INTJ')
pprint(intj_d)
print('Smirnova-Rosser')
intj_sr = words(sr_lemmas_pos, slova, 'INTJ')
pprint(intj_sr)
print('Год жизни в Петербурге')
intj_v = words(v_lemmas_pos, slova, 'INTJ')
pprint(intj_v)
# Out:
# Glinka
# 158
# {'пас', 'есть', 'увы', 'ах', 'стук', 'ура', 'то-то', 'скрип', 'тьфу', 'ух', 'чур', 'виват', '42-му', 'марш'}
# OrderedDict([('ах', 3.79746835443038),
#              ('ура', 10.126582278481013),
#              ('увы', 2.5316455696202533)])
# Lazhechnikov
# 94
# {'эй', 'есть', 'увы', 'ах', 'стук', 'ура', 'виват', 'майна', 'марш'}
# OrderedDict([('ах', 2.127659574468085),
#              ('ура', 19.148936170212767),
#              ('увы', 3.1914893617021276)])
# Davydov
# 36
# {'6-му', 'есть', 'увы', 'ах', '1-му', '23-му', 'ура', 'неужто', '3-му', 'марш'}
# OrderedDict([('ах', 2.7777777777777777),
#              ('ура', 19.444444444444446),
#              ('увы', 8.333333333333332)])
# Durova
# 220
# {'хм', 'ох', 'спасибо', 'гей', 'поди-ка', 'топ', 'стук', 'эх', 'ура', 'марш-марш', 'бис', 'р-му', 'ой', 'марш', 'есть', 'поди', 'виват', 'слушай', 'увы', 'толк', 'ах'}
# OrderedDict([('ах', 29.545454545454547),
#              ('ура', 1.8181818181818181),
#              ('увы', 5.909090909090909)])
# Smirnova-Rosser
# 9
# {'то-то', 'есть'}
# OrderedDict([('ах', 0), ('ура', 0), ('увы', 0)])
# Год жизни в Петербурге
# 92
# {'есть', 'увы', 'ах', 'топ', 'стук', 'э', 'то-то', 'ха'}
# OrderedDict([('ах', 30.434782608695656),
#              ('ура', 0),
#              ('увы', 2.1739130434782608)])

# %%
barWidth = 10
y_pos = [1, 8, 15, 22, 29, 36, 43, 50]
y_pos_one = [y + 1 for y in y_pos]
y_pos_two = [y + 1 for y in y_pos_one]
y_pos_three = [y + 1 for y in y_pos_two]
y_pos_four = [y + 1 for y in y_pos_three]
y_pos_five = [y + 1 for y in y_pos_four]
plt.figure(figsize=(20,12))
plt.bar(y_pos, npro_g.values(), color='skyblue', label = 'Ф. Н. Глинка')
plt.bar(y_pos_one, npro_l.values(), color='blue', label = 'И. И. Лажечников')
plt.bar(y_pos_two, npro_dav.values(), color='cyan', label = 'Д. В. Давыдов')
plt.bar(y_pos_three, npro_d.values(), color='green', label = 'Н. А. Дурова')
plt.bar(y_pos_four, npro_sr.values(), color='magenta', label = 'А. О. Смирнова-Россет')
plt.bar(y_pos_five, npro_v.values(), color='MediumAquamarine', label = 'Год жизни в СПб')
plt.title('Личные местоимения в процентах', fontsize = 16)
plt.legend(fontsize = 16)
plt.xticks(y_pos_two, list(npro_d.keys()), fontsize = 16)
# Out:
# ([<matplotlib.axis.XTick at 0x2b693310>,
#   <matplotlib.axis.XTick at 0x2b6932e0>,
#   <matplotlib.axis.XTick at 0x2b687e20>,
#   <matplotlib.axis.XTick at 0x2d75ad90>,
#   <matplotlib.axis.XTick at 0x2d7682e0>,
#   <matplotlib.axis.XTick at 0x2d7687f0>,
#   <matplotlib.axis.XTick at 0x2d768940>,
#   <matplotlib.axis.XTick at 0x2d768d00>],
#  [Text(3, 0, 'я'),
#   Text(10, 0, 'ты'),
#   Text(17, 0, 'он'),
#   Text(24, 0, 'она'),
#   Text(31, 0, 'оно'),
#   Text(38, 0, 'мы'),
#   Text(45, 0, 'вы'),
#   Text(52, 0, 'они')])

# %%
barWidth = 10
y_pos = [1, 7, 13]
y_pos_one = [y + 1 for y in y_pos]
y_pos_two = [y + 1 for y in y_pos_one]
y_pos_three = [y + 1 for y in y_pos_two]
y_pos_four = [y + 1 for y in y_pos_three]
plt.figure(figsize=(12,12))
plt.bar(y_pos, intj_g.values(), color='skyblue', label = 'Ф. Н. Глинка')
plt.bar(y_pos_one, intj_l.values(), color='blue', label = 'И. И. Лажечников')
plt.bar(y_pos_two, intj_dav.values(), color='cyan', label = 'Д. В. Давыдов')
plt.bar(y_pos_three, intj_d.values(), color='green', label = 'Н. А. Дурова')
plt.bar(y_pos_four, intj_v.values(), color='MediumAquamarine', label = 'Год жизни в СПб')
plt.title('Междометия в процентах', fontsize = 16)
plt.legend(fontsize = 16)
plt.xticks(y_pos_one, list(intj_d.keys()), fontsize = 16)
# Out:
# ([<matplotlib.axis.XTick at 0x2e31a100>,
#   <matplotlib.axis.XTick at 0x2e31a0d0>,
#   <matplotlib.axis.XTick at 0x2e30dca0>],
#  [Text(2, 0, 'ах'), Text(8, 0, 'ура'), Text(14, 0, 'увы')])

# %%
men = {}
for k in g_pos_sort.keys():
    men[k] = g_pos_sort[k]+l_pos_sort[k]+dav_pos_sort[k]
men_total = sum(men.values())
men_pos = {}
for k, v in men.items():
    men_pos[k] = (v/men_total)*100

# %%
all_w = {}
for k in g_pos_sort.keys():
    all_w[k] = g_pos_sort[k]+l_pos_sort[k]+dav_pos_sort[k]+d_pos_sort[k]
all_total = sum(all_w.values())
all_pos = {}
for k, v in all_w.items():
    all_pos[k] = (v/all_total)*100

# %%
barWidth = 10
#y_pos = [1, 7, 13, 19, 25, 31, 37, 43, 49, 55, 61, 67]
y_pos = [1, 8, 15, 22, 29, 36, 43, 50, 57, 64, 71, 78]
y_pos_one = [y + 1 for y in y_pos]
y_pos_two = [y + 1 for y in y_pos_one]
y_pos_three = [y + 1 for y in y_pos_two]
y_pos_four = [y + 1 for y in y_pos_three]
y_pos_five = [y + 1 for y in y_pos_four]
plt.figure(figsize=(20,12))
plt.bar(y_pos, g_pos_sort.values(), color='skyblue', label = 'Ф. Н. Глинка')
plt.bar(y_pos_one, l_pos_sort.values(), color='blue', label = 'И. И. Лажечников')
plt.bar(y_pos_two, dav_pos_sort.values(), color='cyan', label = 'Д. В. Давыдов')
plt.bar(y_pos_three, d_pos_sort.values(), color='green', label = 'Н. А. Дурова, "Записки"')
plt.bar(y_pos_four, sr_pos_sort.values(), color='magenta', label = 'А. О. Смирнова-Россет')
plt.bar(y_pos_five, v_pos_sort.values(), color='limegreen', label = 'Н. А. Дурова, "Год жизни в Петербурге"')
plt.title('Части речи в процентах', fontsize = 16)
plt.legend(fontsize = 16)
plt.xticks(y_pos_two, l_pos_sort.keys(), rotation=20, fontsize = 16)
# Out:
# ([<matplotlib.axis.XTick at 0x30caef10>,
#   <matplotlib.axis.XTick at 0x30caeee0>,
#   <matplotlib.axis.XTick at 0x30cdaa90>,
#   <matplotlib.axis.XTick at 0x304fbca0>,
#   <matplotlib.axis.XTick at 0x304ff1f0>,
#   <matplotlib.axis.XTick at 0x304ff700>,
#   <matplotlib.axis.XTick at 0x304ffc10>,
#   <matplotlib.axis.XTick at 0x30525160>,
#   <matplotlib.axis.XTick at 0x30525670>,
#   <matplotlib.axis.XTick at 0x30525b80>,
#   <matplotlib.axis.XTick at 0x304f60d0>,
#   <matplotlib.axis.XTick at 0x304f65e0>],
#  [Text(3, 0, 'NOUN'),
#   Text(10, 0, 'VERB'),
#   Text(17, 0, 'ADJ'),
#   Text(24, 0, 'PREP'),
#   Text(31, 0, 'CONJ'),
#   Text(38, 0, 'NPRO'),
#   Text(45, 0, 'ADVB'),
#   Text(52, 0, 'PRCL'),
#   Text(59, 0, 'NUMR'),
#   Text(66, 0, 'COMP'),
#   Text(73, 0, 'PRED'),
#   Text(80, 0, 'INTJ')])

# %%
barWidth = 10
y_pos = [1, 5, 9, 13, 17, 21, 25, 29, 33, 37, 41, 45]
y_pos_one = [y + 1 for y in y_pos]
y_pos_two = [y + 1 for y in y_pos_one]
y_pos_three = [y + 1 for y in y_pos_two]
y_pos_four = [y + 1 for y in y_pos_three]
y_pos_five = [y + 1 for y in y_pos_four]
plt.figure(figsize=(20,12))
plt.bar(y_pos, g_pos_sort.values(), color='lightblue', edgecolor = 'black', label = 'FNG')
plt.bar(y_pos_one, l_pos_sort.values(), color='cornflowerblue', edgecolor = 'black', label = 'IIL')
plt.bar(y_pos_two, dav_pos_sort.values(), color='cyan', edgecolor = 'black', label = 'DVD')
plt.plot(y_pos_one, d_pos_sort.values(), color='green', marker = '*', label = 'NAD')
plt.plot(y_pos_one, sr_pos_sort.values(), color='magenta', label = 'А. О. Смирнова-Россет')
plt.plot(y_pos_one, v_pos_sort.values(), color='HotPink', label = 'З. А. Волконская')
plt.plot(y_pos_one, men_pos.values(), color='navy', label = 'AvgMen', marker = 'o')
plt.title('Part of Speech')
plt.legend()
plt.xticks(y_pos_one, l_pos_sort.keys(), rotation=20)
# Out:
# ([<matplotlib.axis.XTick at 0x2d972dc0>,
#   <matplotlib.axis.XTick at 0x2d972d90>,
#   <matplotlib.axis.XTick at 0x2d96c910>,
#   <matplotlib.axis.XTick at 0x2da1f460>,
#   <matplotlib.axis.XTick at 0x2da1f7f0>,
#   <matplotlib.axis.XTick at 0x2da1fa90>,
#   <matplotlib.axis.XTick at 0x2da1ffa0>,
#   <matplotlib.axis.XTick at 0x2da264f0>,
#   <matplotlib.axis.XTick at 0x2da26a00>,
#   <matplotlib.axis.XTick at 0x2da26f10>,
#   <matplotlib.axis.XTick at 0x2da2b460>,
#   <matplotlib.axis.XTick at 0x2da2b970>],
#  [Text(2, 0, 'NOUN'),
#   Text(6, 0, 'VERB'),
#   Text(10, 0, 'ADJ'),
#   Text(14, 0, 'PREP'),
#   Text(18, 0, 'CONJ'),
#   Text(22, 0, 'NPRO'),
#   Text(26, 0, 'ADVB'),
#   Text(30, 0, 'PRCL'),
#   Text(34, 0, 'NUMR'),
#   Text(38, 0, 'COMP'),
#   Text(42, 0, 'PRED'),
#   Text(46, 0, 'INTJ')])

# %%
plt.figure(figsize=(12,7))
plt.plot(d_pos_sort.values(), color='green', marker = '*', markersize = 10, label = 'Н. А. Дурова', linewidth = 3)
plt.plot(sr_pos_sort.values(), color='magenta', label = 'А. О. Смирнова-Россет', linewidth = 3,)
plt.plot(v_pos_sort.values(), color='hotpink', label = 'З. А. Волконская', linewidth = 3)
plt.plot(men_pos.values(), color='navy', label = 'Другие, в среднем', linewidth = 3,)
plt.title('Части речи в процентах', fontsize = 16)
plt.legend(fontsize = 16)
plt.xticks(np.arange(12), l_pos_sort.keys(), rotation=20, fontsize = 16)
# Out:
# ([<matplotlib.axis.XTick at 0x2d82e760>,
#   <matplotlib.axis.XTick at 0x2d82e790>,
#   <matplotlib.axis.XTick at 0x2b68cc10>,
#   <matplotlib.axis.XTick at 0x2da26670>,
#   <matplotlib.axis.XTick at 0x2d9d63a0>,
#   <matplotlib.axis.XTick at 0x2d966280>,
#   <matplotlib.axis.XTick at 0x2d94fc40>,
#   <matplotlib.axis.XTick at 0x2d867c10>,
#   <matplotlib.axis.XTick at 0x2d939dc0>,
#   <matplotlib.axis.XTick at 0x2d9a9850>,
#   <matplotlib.axis.XTick at 0x2d9f4790>,
#   <matplotlib.axis.XTick at 0x2da3abe0>],
#  [Text(0, 0, 'NOUN'),
#   Text(1, 0, 'VERB'),
#   Text(2, 0, 'ADJ'),
#   Text(3, 0, 'PREP'),
#   Text(4, 0, 'CONJ'),
#   Text(5, 0, 'NPRO'),
#   Text(6, 0, 'ADVB'),
#   Text(7, 0, 'PRCL'),
#   Text(8, 0, 'NUMR'),
#   Text(9, 0, 'COMP'),
#   Text(10, 0, 'PRED'),
#   Text(11, 0, 'INTJ')])

# %%
plt.plot(d_pos_sort.values(), color='green', marker = '*', label = 'Н. А. Дурова')
plt.plot(sr_pos_sort.values(), color='magenta', label = 'А. О. Смирнова-Россет')
plt.plot(v_pos_sort.values(), color='hotpink', label = 'З. А. Волконская', linewidth = 3)
plt.plot(men_pos.values(), color='navy', label = 'Другие, в среднем')
plt.plot(all_pos.values(), color='gray', label = 'Всего, в среднем')
plt.title('Части речи в процентах')
plt.legend()
plt.xticks(np.arange(12), l_pos_sort.keys(), rotation=20)
# Out:
# ([<matplotlib.axis.XTick at 0x2e1d6be0>,
#   <matplotlib.axis.XTick at 0x2e1d6bb0>,
#   <matplotlib.axis.XTick at 0x2e1ce490>,
#   <matplotlib.axis.XTick at 0x2dac7850>,
#   <matplotlib.axis.XTick at 0x2dac7d60>,
#   <matplotlib.axis.XTick at 0x2dacd2b0>,
#   <matplotlib.axis.XTick at 0x2dacd7c0>,
#   <matplotlib.axis.XTick at 0x2dacdcd0>,
#   <matplotlib.axis.XTick at 0x2dad5220>,
#   <matplotlib.axis.XTick at 0x2dacd490>,
#   <matplotlib.axis.XTick at 0x2dac7520>,
#   <matplotlib.axis.XTick at 0x2dad5610>],
#  [Text(0, 0, 'NOUN'),
#   Text(1, 0, 'VERB'),
#   Text(2, 0, 'ADJ'),
#   Text(3, 0, 'PREP'),
#   Text(4, 0, 'CONJ'),
#   Text(5, 0, 'NPRO'),
#   Text(6, 0, 'ADVB'),
#   Text(7, 0, 'PRCL'),
#   Text(8, 0, 'NUMR'),
#   Text(9, 0, 'COMP'),
#   Text(10, 0, 'PRED'),
#   Text(11, 0, 'INTJ')])

# %%
plt.figure(figsize=(15,12))
h = [13.9, 18.9, 23.1, 18.0, 15.3, 16.6]
plt.bar(1, [13.9], color='skyblue', label = 'Ф. Н. Глинка')
plt.bar(2, [18.9], color='blue', label = 'И. И. Лажечников')
plt.bar(3, [23.1], color='cyan', label = 'Д. В. Давыдов')
plt.bar(4, [18.0], color='green', label = 'Н. А. Дурова')
plt.bar(5, [15.3], color='magenta', label = 'А. О. Смирнова-Россет')
plt.bar(6, [16.6], color='HotPink', label = 'З. А. Волконская')
plt.title('Средняя длина предложения в словах', fontsize = 16)
plt.legend(fontsize = 16)
labels = ['13,9', '18,9', '23,1', '18,0', '15,3', '16,6']
for i in range(1, 7):
    plt.text(i-0.25, y = h[i-1]+0.2, s = labels[i-1], size = 16)
#plt.xticks([1, 2, 3, 4, 5, 6], ('G', 'L', 'D', 'D', 'S', 'V'), rotation=20, fontsize = 14)

# %%
def read_clean(file, new_file):
    with open (file, encoding = 'utf-8') as f:
        my_text = f.readlines()
    for line in my_text:
        l = m.lemmatize(line)
        words = [w.lower() for w in l if w.isalpha()]
        line = ' '.join(words)
        with open (new_file, encoding = 'utf-8', mode = 'a') as n_f:
            n_f.write(line+'\n')
    return new_file

# %%
#t_g = read_clean('Glinka.txt', 'lemmas_Glinka.txt')
#print('Done!')
#t_l = read_clean('Lazhechnikov.txt', 'lemmas_Lazhechnikov.txt')
#print('Done!')
#t_dav = read_clean('Davydov.txt', 'lemmas_Davydov.txt')
#print('Done!')
#t_d = read_clean('Durova.txt', 'lemmas_Durova.txt')
#print('Done!')
#t_sr = read_clean('smirnova-rosset.txt', 'lemmas_Smirnova_Rosset.txt')
t_v = read_clean('Volkonskaya.txt', 'lemmas_Volkonskaya.txt')
#print('Done!')

# %%
t_g = 'lemmas_Glinka.txt'
t_l = 'lemmas_Lazhechnikov.txt'
t_dav = 'lemmas_Davydov.txt'
t_d = 'lemmas_Durova.txt'

# %%
def grey_color_func(word, font_size, position, orientation, random_state=None,
                    **kwargs):
    return "hsl(0, 0%%, %d%%)" % random.randint(80, 100)

def cloud(df, my_title, bg, color):
#def cloud(df, my_title, bg):
    bad = ["этот", "весь", "свой", "это", "который"]
    stops = set(stopwords.words('russian'))
    text = ' '.join([word for word in df['lemma'].values if word not in stops and word not in bad])
    wordcloud = WordCloud(
        background_color =bg,
        colormap = color,
        width = 1500,
        height = 1500, 
    ).generate(text)
    plt.figure(figsize = (10, 10), facecolor = None) 
    #plt.imshow(wordcloud.recolor(color_func=grey_color_func, random_state=3),
           #interpolation="bilinear")
    plt.imshow(wordcloud)
    plt.axis("off") 
    plt.title(my_title)
    plt.show()

# %%
cloud(gg_df,'Ф. Н. Глинка', 'white', 'winter')

# %%
cloud(ll_df, 'И. И. Лажечников','white', 'winter')

# %%
cloud(ddav_df,'Д. В. Давыдов' , 'white', 'winter')

# %%
cloud(dd_df, 'Н. А. Дурова', 'white', 'winter')

# %% [markdown]
# Можно ещё покраисть фон в какой-нибудь цвет, а слова выделить серым (но это не важно, только для красоты):
# <img src = 'https://raw.githubusercontent.com/YanaKoko/1812/main/облако.JPG'>

# %%
cloud(ssrr_df, 'А. О. Смирнова-Россет', 'white', 'winter')

# %% [markdown]
# Тут я пыталась искать синонимы и прочие семантические штуки, но вышло плохо.

# %%
#data = gensim.models.word2vec.LineSentence(t_g)
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#g_model = gensim.models.Word2Vec(data, size=300, window=10, min_count=5, iter = 6)

# %%
#data = gensim.models.word2vec.LineSentence(t_l)
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#l_model = gensim.models.Word2Vec(data, size=300, window=10, min_count=5, iter = 6)

# %%
#data = gensim.models.word2vec.LineSentence(t_dav)
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#dav_model = gensim.models.Word2Vec(data, size=300, window=10, min_count=5, iter = 6)

# %%
#data = gensim.models.word2vec.LineSentence(t_d)
#logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
#d_model = gensim.models.Word2Vec(data, size=300, window=10, min_count=5, iter = 6)

# %%
#g_model.wv.most_similar("не", topn=15)

# %%
#l_model.wv.most_similar("не", topn=15)

# %%
#dav_model.wv.most_similar("не", topn=15)

# %%
#d_model.wv.most_similar("не", topn=15)

# %%
#g_model.wv.most_similar(positive=["ты", "я"], negative=["мы"], topn=3)

# %%
#l_model.wv.most_similar(positive=["ты", "я"], negative=["мы"], topn=3)

# %%
#dav_model.wv.most_similar(positive=["ты", "я"], negative=["мы"], topn=3)

# %%
#d_model.wv.most_similar(positive=["мой", "твой"], negative=["я"], topn=3)

# %%
def names(text):
    my_names = []
    ne = NamesExtractor()
    le = LocationExtractor()
    res = ne(text)
    for i in range(len(res)):
        if i % 2 == 0:
            value = f'{res[i].fact.first or ""} {res[i].fact.middle or ""} {res[i].fact.last or ""}'.strip()
            my_names.append(value)
    res_two = le(text)
    for i in range(len(res_two)):
        if i % 2 == 0:
            value = res_two[i].fact.name
            my_names.append(value)
    return(my_names)


def people(text):
    my_names = []
    ne = NamesExtractor()
    res = ne(text)
    for i in range(len(res)):
        if i % 2 == 0:
            value = f'{res[i].fact.first or ""} {res[i].fact.middle or ""} {res[i].fact.last or ""}'.strip()
            my_names.append(value)
    return(my_names)


def places(text):
    my_names = []
    le = LocationExtractor()
    res_two = le(text)
    for i in range(len(res_two)):
        if i % 2 == 0:
            value = res_two[i].fact.name
            my_names.append(value)
    return(my_names)

# %%
def text(file):
    with open (file, encoding = 'utf-8') as f:
        text = f.read()
    return text

# %%
g_text = text('Glinka.txt')
l_text = text('Lazhechnikov.txt')
dav_text = text('Davydov.txt')
d_text = text('Durova.txt')
sr_text = text('smirnova-rosset.txt')
v_text = text('Volkonskaya.txt')

# %%
g_names = names(g_text)
g_people = people(g_text)
g_places = places(g_text)

# %%
l_names = names(l_text)
l_people = people(l_text)
l_places = places(l_text)

# %%
dav_names = names(dav_text)
dav_people = people(dav_text)
dav_places = places(dav_text)

# %%
d_names = names(d_text)
d_people = people(d_text)
d_places = places(d_text)

# %%
sr_names = names(sr_text)
sr_people = people(sr_text)
sr_places = places(sr_text)

# %%
v_names = names(v_text)
v_people = people(v_text)
v_places = places(v_text)

# %%
print('Glinka')
pprint(Counter(g_names).most_common(20))
print('Lazhechnikov')
pprint(Counter(l_names).most_common(20))
print('Davydov')
pprint(Counter(dav_names).most_common(20))
print('Durova')
pprint(Counter(d_names).most_common(20))
print('Smirnova-Rosset')
pprint(Counter(sr_names).most_common(20))
print('Volkonskaya')
pprint(Counter(v_names).most_common(20))
# Out:
# Glinka
# [('великое', 58),
#  ('париж', 54),
#  ('россия', 46),
#  ('варшава', 46),
#  ('то', 36),
#  ('франция', 29),
#  ('европа', 29),
#  ('дрезден', 28),
#  ('москва', 27),
#  ('нея', 23),
#  ('сим', 19),
#  ('май', 16),
#  ('висла', 15),
#  ('польша', 14),
#  ('саксония', 14),
#  ('блюхер', 13),
#  ('смоленск', 13),
#  ('марна', 13),
#  ('эльба', 12),
#  ('рейн', 12)]
# Lazhechnikov
# [('великое', 25),
#  ('то', 25),
#  ('москва', 18),
#  ('россия', 16),
#  ('нея', 13),
#  ('франция', 12),
#  ('париж', 11),
#  ('александр', 9),
#  ('польша', 9),
#  ('европа', 8),
#  ('который', 8),
#  ('грозный', 7),
#  ('германия', 7),
#  ('берлин', 7),
#  ('монмартр', 6),
#  ('мирный', 6),
#  ('фредерик', 5),
#  ('траяна', 5),
#  ('густав', 5),
#  ('вартбург', 5)]
# Davydov
# [('чичагов', 28),
#  ('ермол', 27),
#  ('вязьма', 27),
#  ('кутузов', 26),
#  ('ермолов', 25),
#  ('сеславина', 20),
#  ('смоленск', 18),
#  ('березина', 18),
#  ('витгенштейн', 17),
#  ('то', 16),
#  ('нея', 14),
#  ('фигнер', 13),
#  ('денисов', 13),
#  ('москва', 13),
#  ('россия', 12),
#  ('коновницын', 10),
#  ('дохтуров', 10),
#  ('юхнов', 10),
#  ('баталион', 10),
#  ('малоярославец', 10)]
# Durova
# [('нея', 67),
#  ('то', 58),
#  ('алкида', 52),
#  ('куда', 39),
#  ('александр', 28),
#  ('алкид', 23),
#  ('хамитулла', 19),
#  ('который', 18),
#  ('подъямпольский', 16),
#  ('зугра', 14),
#  ('малороссия', 13),
#  ('россия', 13),
#  ('ефим', 12),
#  ('москва', 12),
#  ('сабля', 12),
#  ('вагенбург', 11),
#  ('штакельберг', 10),
#  ('дуров', 9),
#  ('дон', 9),
#  ('цеддельман', 9)]
# Smirnova-Rosset
# [('нессельрод', 6),
#  ('россия', 5),
#  ('орлов', 4),
#  ('чернышев', 4),
#  ('рим', 4),
#  ('александр', 3),
#  ('гоголь', 3),
#  ('волконский', 3),
#  ('уваров', 3),
#  ('нея', 3),
#  ('кавказ', 3),
#  ('тютчев', 2),
#  ('михаил павлович', 2),
#  ('конст', 2),
#  ('суворов', 2),
#  ('крюднер', 2),
#  ('адлерберг', 2),
#  ('елизавета алексеевна', 2),
#  ('богемия', 2),
#  ('мюллер', 2)]
# Volkonskaya
# [('великое', 5),
#  ('италия', 5),
#  ('май', 4),
#  ('альп', 3),
#  ('нея', 3),
#  ('мария', 2),
#  ('лаура', 2),
#  ('харон', 2),
#  ('куда', 2),
#  ('падуя', 2),
#  ('гете', 1),
#  ('рюисдаля', 1),
#  ('роза', 1),
#  ('пушкин', 1),
#  ('шекспир', 1),
#  ('герена', 1),
#  ('байрон', 1),
#  ('лафатер', 1),
#  ('джиотто', 1),
#  ('рафаэль', 1)]

# %%
def percent(my_list):
    i = 0
    start = 300
    new = {}
    l = len(my_list)
    count = Counter(my_list).most_common()
    for c in range(len(count)):
        if count[c][1] < start:
            i += 1
            start = count[c][1]
        new[count[c][0]] = [{'perc': (count[c][1]/l)*100, 'abs': count[c][1], 'count': i}]
        #if i += 1
        #print(i)
    return new

# %%
#percent(g_people)

# %%
#percent(l_people)

# %%
#percent(dav_people)

# %%
#percent(d_people)

# %%
d_clean = [p for p in d_people if p != 'алкида']
#percent(d_clean)
